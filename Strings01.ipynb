# %% [markdown]
# <a href="https://colab.research.google.com/github/mazidgaba/Python/blob/main/Strings01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ensure 'print' is not redefined
try:
    del print
except NameError:
    pass

name = 'Mazid Gaba'
add = "Siwan, Bihar"
print(name)
print(add)


About = '''My name is Mazid Gaba,
          I am Student of JNU,
          I am from Siwan, Bihar.'''
print(About)

print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
print(name[0])
print(name[0])
print(name[8])
print(name[3])

for character in name:
    print(character)

for character in About:
    print(character)
# Out:
# Mazid Gaba
# Siwan, Bihar
# My name is Mazid Gaba,
#           I am Student of JNU,
#           I am from Siwan, Bihar.
# M
# a
# z
# i
# d
#
# M
# M
# b
# i
# M
# a
# z
# i
# d
#
# G
# a
# b
# a
# M
# y
#
# n
# a
# m
# e
#
# i
# s
#
# M
# a
# z
# i
# d
#
# G
# a
# b
# a
# ,
#
#
#
#
#
#
#
#
#
#
#
#
# I
#
# a
# m
#
# S
# t
# u
# d
# e
# n
# t
#
# o
# f
#
# J
# N
# U
# ,
#
#
#
#
#
#
#
#
#
#
#
#
# I
#
# a
# m
#
# f
# r
# o
# m
#
# S
# i
# w
# a
# n
# ,
#
# B
# i
# h
# a
# r
# .
